# %% [markdown]
# <a href="https://colab.research.google.com/github/shuangquan-li-con/ECON5200-37499-Applied-Data-Analytics-in-Economics/blob/main/question%20of%20lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data={
    "Country":['United States','Argentina','Australia','Brazil','Britain','China','Egypt','Euro area','Hong Kong','Indonesia','Japan','Mexico','Norway','Pakistan','Philippines','Russia','Saudi Arabia','South Afica','South Korea'],
    "iso_a3":['USA','ARG','AUS','BRA','GBR','CHN','EGY','EUZ','HKG','IDN','JPN','MEX','NOR','PAK','PHL','RUS','SAU','ZAF','KOR'],
    "local_price":[4.79,28.00,5.30,13.50,2.89,17.20,16.93,3.68,18.80,27939,370,49.00,48.00,300,163,89.00,11.00,25.50,4100],
    "dollar_ex":[1.00,8.62,1.23,2.59,0.66,6.21,7.36,0.86,7.74,12472,117.83,14.63,7.62,100.67,44.41,65.44,3.75,11.49,1084.66]
}

# %%
df=pd.DataFrame(data)

# %%
print(df)
# Out:
#           Country iso_a3  local_price  dollar_ex
# 0   United States    USA         4.79       1.00
# 1       Argentina    ARG        28.00       8.62
# 2       Australia    AUS         5.30       1.23
# 3          Brazil    BRA        13.50       2.59
# 4         Britain    GBR         2.89       0.66
# 5           China    CHN        17.20       6.21
# 6           Egypt    EGY        16.93       7.36
# 7       Euro area    EUZ         3.68       0.86
# 8       Hong Kong    HKG        18.80       7.74
# 9       Indonesia    IDN     27939.00   12472.00
# 10          Japan    JPN       370.00     117.83
# 11         Mexico    MEX        49.00      14.63
# 12         Norway    NOR        48.00       7.62
# 13       Pakistan    PAK       300.00     100.67
# 14    Philippines    PHL       163.00      44.41
# 15         Russia    RUS        89.00      65.44
# 16   Saudi Arabia    SAU        11.00       3.75
# 17    South Afica    ZAF        25.50      11.49
# 18    South Korea    KOR      4100.00    1084.66

# %%
print(df.head())
# Out:
#          Country iso_a3  local_price  dollar_ex
# 0  United States    USA         4.79       1.00
# 1      Argentina    ARG        28.00       8.62
# 2      Australia    AUS         5.30       1.23
# 3         Brazil    BRA        13.50       2.59
# 4        Britain    GBR         2.89       0.66

# %%
print(df.tail())
# Out:
#          Country iso_a3  local_price  dollar_ex
# 14   Philippines    PHL        163.0      44.41
# 15        Russia    RUS         89.0      65.44
# 16  Saudi Arabia    SAU         11.0       3.75
# 17   South Afica    ZAF         25.5      11.49
# 18   South Korea    KOR       4100.0    1084.66

# %%
df=df.dropna()

# %%
df['dollar_price']=df['local_price']/df['dollar_ex']

# %%
us_price=df.loc[df['iso_a3']=='USA','dollar_ex'].values

# %%
us_price=df.loc[df['iso_a3']=='USA','dollar_ex'].values

# %%
df['implied_ppp']=df['local_price']/us_price

# %%
df['valuation']=(df['implied_ppp']-df['dollar_ex'])/df['dollar_ex']

# %%
df['valuation_pct']=df['valuation']*100

# %%
print(df[['Country','dollar_price','valuation_pct']].sort_values('valuation_pct'))
# Out:
#           Country  dollar_price  valuation_pct
# 15         Russia      1.360024      36.002445
# 17    South Afica      2.219321     121.932115
# 9       Indonesia      2.240138     124.013791
# 6           Egypt      2.300272     130.027174
# 8       Hong Kong      2.428941     142.894057
# 5           China      2.769726     176.972625
# 16   Saudi Arabia      2.933333     193.333333
# 13       Pakistan      2.980034     198.003377
# 10          Japan      3.140117     214.011712
# 1       Argentina      3.248260     224.825986
# 11         Mexico      3.349282     234.928230
# 14    Philippines      3.670345     267.034452
# 18    South Korea      3.779986     277.998636
# 7       Euro area      4.279070     327.906977
# 2       Australia      4.308943     330.894309
# 4         Britain      4.378788     337.878788
# 0   United States      4.790000     379.000000
# 3          Brazil      5.212355     421.235521
# 12         Norway      6.299213     529.921260

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='valuation_pct',y='Country',data=df.sort_values('valuation_pct'),palette='vlag')
plt.axvline(x=0,color='black',linestyle='--')
plt.title('The Big Mac Index: Currency Valuation vs USD (Jan 2025)')
plt.xlabel('% Under/Over Values relative to USD')
plt.legend()
plt.show()
# Out:
# /tmp/ipython-input-3537025195.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='valuation_pct',y='Country',data=df.sort_values('valuation_pct'),palette='vlag')
# /tmp/ipython-input-3537025195.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=data

# %%
df=pd.DataFrame(data)

# %%
print(df)
# Out:
#           Country iso_a3  local_price  dollar_ex
# 0   United States    USA         4.79       1.00
# 1       Argentina    ARG        28.00       8.62
# 2       Australia    AUS         5.30       1.23
# 3          Brazil    BRA        13.50       2.59
# 4         Britain    GBR         2.89       0.66
# 5           China    CHN        17.20       6.21
# 6           Egypt    EGY        16.93       7.36
# 7       Euro area    EUZ         3.68       0.86
# 8       Hong Kong    HKG        18.80       7.74
# 9       Indonesia    IDN     27939.00   12472.00
# 10          Japan    JPN       370.00     117.83
# 11         Mexico    MEX        49.00      14.63
# 12         Norway    NOR        48.00       7.62
# 13       Pakistan    PAK       300.00     100.67
# 14    Philippines    PHL       163.00      44.41
# 15         Russia    RUS        89.00      65.44
# 16   Saudi Arabia    SAU        11.00       3.75
# 17    South Afica    ZAF        25.50      11.49
# 18    South Korea    KOR      4100.00    1084.66

# %%
df['dollar_price']=df['local_price']/df['dollar_ex']

# %%
print(df)
# Out:
#           Country iso_a3  local_price  dollar_ex  dollar_price
# 0   United States    USA         4.79       1.00      4.790000
# 1       Argentina    ARG        28.00       8.62      3.248260
# 2       Australia    AUS         5.30       1.23      4.308943
# 3          Brazil    BRA        13.50       2.59      5.212355
# 4         Britain    GBR         2.89       0.66      4.378788
# 5           China    CHN        17.20       6.21      2.769726
# 6           Egypt    EGY        16.93       7.36      2.300272
# 7       Euro area    EUZ         3.68       0.86      4.279070
# 8       Hong Kong    HKG        18.80       7.74      2.428941
# 9       Indonesia    IDN     27939.00   12472.00      2.240138
# 10          Japan    JPN       370.00     117.83      3.140117
# 11         Mexico    MEX        49.00      14.63      3.349282
# 12         Norway    NOR        48.00       7.62      6.299213
# 13       Pakistan    PAK       300.00     100.67      2.980034
# 14    Philippines    PHL       163.00      44.41      3.670345
# 15         Russia    RUS        89.00      65.44      1.360024
# 16   Saudi Arabia    SAU        11.00       3.75      2.933333
# 17    South Afica    ZAF        25.50      11.49      2.219321
# 18    South Korea    KOR      4100.00    1084.66      3.779986

# %%
us_price=df.loc[df['iso_a3']=='USA','dollar_price'].values

# %%
df['implied_ppp']=df['local_price']/us_price

# %%
print(df)
# Out:
#           Country iso_a3  local_price  dollar_ex  dollar_price  implied_ppp
# 0   United States    USA         4.79       1.00      4.790000     1.000000
# 1       Argentina    ARG        28.00       8.62      3.248260     5.845511
# 2       Australia    AUS         5.30       1.23      4.308943     1.106472
# 3          Brazil    BRA        13.50       2.59      5.212355     2.818372
# 4         Britain    GBR         2.89       0.66      4.378788     0.603340
# 5           China    CHN        17.20       6.21      2.769726     3.590814
# 6           Egypt    EGY        16.93       7.36      2.300272     3.534447
# 7       Euro area    EUZ         3.68       0.86      4.279070     0.768267
# 8       Hong Kong    HKG        18.80       7.74      2.428941     3.924843
# 9       Indonesia    IDN     27939.00   12472.00      2.240138  5832.776618
# 10          Japan    JPN       370.00     117.83      3.140117    77.244259
# 11         Mexico    MEX        49.00      14.63      3.349282    10.229645
# 12         Norway    NOR        48.00       7.62      6.299213    10.020877
# 13       Pakistan    PAK       300.00     100.67      2.980034    62.630480
# 14    Philippines    PHL       163.00      44.41      3.670345    34.029228
# 15         Russia    RUS        89.00      65.44      1.360024    18.580376
# 16   Saudi Arabia    SAU        11.00       3.75      2.933333     2.296451
# 17    South Afica    ZAF        25.50      11.49      2.219321     5.323591
# 18    South Korea    KOR      4100.00    1084.66      3.779986   855.949896

# %%
df['valuation']=(df['implied_ppp']-df['dollar_ex'])/df['dollar_ex']

# %%
df['valuation_pct']=df['valuation']*100

# %%
print(df[['Country','dollar_price','valuation_pct']].sort_values('valuation_pct'))
# Out:
#           Country  dollar_price  valuation_pct
# 15         Russia      1.360024     -71.607005
# 17    South Afica      2.219321     -53.667617
# 9       Indonesia      2.240138     -53.233029
# 6           Egypt      2.300272     -51.977625
# 8       Hong Kong      2.428941     -49.291429
# 5           China      2.769726     -42.176905
# 16   Saudi Arabia      2.933333     -38.761308
# 13       Pakistan      2.980034     -37.786351
# 10          Japan      3.140117     -34.444319
# 1       Argentina      3.248260     -32.186642
# 11         Mexico      3.349282     -30.077614
# 14    Philippines      3.670345     -23.374854
# 18    South Korea      3.779986     -21.085880
# 7       Euro area      4.279070     -10.666602
# 2       Australia      4.308943     -10.042942
# 4         Britain      4.378788      -8.584804
# 0   United States      4.790000       0.000000
# 3          Brazil      5.212355       8.817437
# 12         Norway      6.299213      31.507570

# %%
plt.figure(figsize=(10,6))
sns.barplot(y='Country',x='valuation_pct',data=df.sort_values('valuation_pct'),palette='vlag')
plt.title('The Big Mac Index')
plt.axvline(x=0,color='black',linestyle='--')
plt.xlabel('%')
plt.show()
# Out:
# /tmp/ipython-input-4093105525.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y='Country',x='valuation_pct',data=df.sort_values('valuation_pct'),palette='vlag')
