# %% [markdown]
# <a href="https://colab.research.google.com/github/shuangquan-li-con/ECON5200-37499-Applied-Data-Analytics-in-Economics/blob/main/untitled26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
np.random.randint(9999,99999)
# Out:
# 24754

# %%
85962
# Out:
# 85962

# %%
import numpy as np
import matplotlib.pyplot as plt
def simulate_law_of_large_numbers(n_flips):
    # Simulate n_flips of a fair coin (0 or 1)
    flips = np.random.randint(0, 2, size=n_flips)
    cumulative_averages = np.cumsum(flips) / np.arange(1, n_flips + 1)
    print(flips)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Re-calculate cumulative_averages here
n_flips = 1000  # You can adjust the number of flips as needed
flips = np.random.randint(0, 2, size=n_flips)
cumulative_averages = np.cumsum(flips) / np.arange(1, n_flips + 1)

plt.figure(figsize=(12, 6))
plt.plot(cumulative_averages, label='Cumulative Probability of Heads')
plt.axhline(0.5, color='red', linestyle='--', label='Theoretical Probability (0.5)')
plt.title('The Law of Large Numbers: Convergence to the Mean')
plt.xlabel('Number of Flips')
plt.ylabel('Proportion of Heads')
plt.legend()
plt.show()
simulate_law_of_large_numbers(5000)
# Out:
# [0 0 1 ... 0 1 0]

# %%
import numpy as np
import matplotlib.pyplot as plt

def simulate_law_of_large_numbers(n_flips):
    if n_flips > 1:
        # Simulate n_flips of a fair coin (0 or 1)
        flips = np.random.choice([0, 1], size=n_flips, p=[0.2, 0.8])

        # Calculate cumulative average
        # cumsum adds them up sequentially
        # Divide by range(1, n+1) to get average at each step
        cumulative_averages = np.cumsum(flips) / np.arange(1, n_flips + 1)

        # Visualization
        plt.figure(figsize=(12, 6))
        plt.plot(cumulative_averages, label='Cumulative Probability of Heads')
        plt.axhline(0.5, color='red', linestyle='--', label='Theoretical Probability (0.5)')
        plt.title('The Law of Large Numbers: Convergence to the Mean')
        plt.xlabel('Number of Flips')
        plt.ylabel('Proportion of Heads')
        plt.legend()
        plt.show()
    else:
        print("Enter the number of flip greater than 1")

# Run the simulation
simulate_law_of_large_numbers(10000)

# %%
import numpy as np
songs=['SongA','SongB','SongC']
n_plays=20
playlist_random=np.random.choice(songs,size=n_plays)
playlist_engineer=[]
last_song=None
for _ in range(n_plays):
  allowed=[s for s in songs if s!=last_song]
  pick=np.random.choice(allowed)
  playlist_engineer.append(pick)
  last_song = pick # Update last_song for the next iteration
print(playlist_random)
print(playlist_engineer)
# Out:
# ['SongC' 'SongB' 'SongB' 'SongB' 'SongC' 'SongB' 'SongB' 'SongB' 'SongA'
#  'SongC' 'SongB' 'SongB' 'SongB' 'SongA' 'SongA' 'SongB' 'SongA' 'SongC'
#  'SongB' 'SongB']
# [np.str_('SongC'), np.str_('SongB'), np.str_('SongC'), np.str_('SongA'), np.str_('SongC'), np.str_('SongB'), np.str_('SongA'), np.str_('SongC'), np.str_('SongA'), np.str_('SongC'), np.str_('SongB'), np.str_('SongC'), np.str_('SongA'), np.str_('SongB'), np.str_('SongA'), np.str_('SongC'), np.str_('SongA'), np.str_('SongB'), np.str_('SongC'), np.str_('SongA')]

# %%
def calculate_probability_of_cheating(base_rate,sensitivity,specificity):
  population=1000
  cheaters=population*base_rate
  honest=population*(1-base_rate)
  true_positice=cheaters*sensitivity
