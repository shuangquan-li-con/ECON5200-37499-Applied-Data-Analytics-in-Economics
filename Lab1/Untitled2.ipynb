# %%
# Step 1:
import pandas as pd
import numpy as np
data = {
    'Country':[],
    'iso_a3':[],
    'local_price':[],
    'dollar_ex':[]
}
df = pd.DataFrame(data)
print(df)
# Out:
# Empty DataFrame
# Columns: [Country, iso_a3, local_price, dollar_ex]
# Index: []
